# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting xgboost
#   Downloading xgboost-2.1.0-py3-none-manylinux_2_28_x86_64.whl (153.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.9/153.9 MB 13.3 MB/s eta 0:00:00
# Collecting yfinance
#   Downloading yfinance-0.2.40-py2.py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from xgboost->-r ./requirements.txt (line 1)) (1.23.4)
# Collecting nvidia-nccl-cu12
#   Downloading nvidia_nccl_cu12-2.22.3-py3-none-manylinux2014_x86_64.whl (190.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from xgboost->-r ./requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: lxml>=4.9.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from yfinance->-r ./requirements.txt (line 2)) (4.9.1)
# Collecting platformdirs>=2.0.0
#   Downloading platformdirs-4.2.2-py3-none-any.whl (18 kB)
# Collecting peewee>=3.16.2
#   Downloading peewee-3.17.5.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 93.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pandas>=1.3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from yfinance->-r ./requirements.txt (line 2)) (2.1.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from yfinance->-r ./requirements.txt (line 2)) (4.11.1)
# Requirement already satisfied: pytz>=2022.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from yfinance->-r ./requirements.txt (line 2)) (2022.5)
# Collecting requests>=2.31
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 15.1 MB/s eta 0:00:00
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 22.6 MB/s eta 0:00:00
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.4.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.8/116.8 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance->-r ./requirements.txt (line 2)) (2.3.2.post1)
# Requirement already satisfied: webencodings in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from html5lib>=1.1->yfinance->-r ./requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: six>=1.9 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from html5lib>=1.1->yfinance->-r ./requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance->-r ./requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.31->yfinance->-r ./requirements.txt (line 2)) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.31->yfinance->-r ./requirements.txt (line 2)) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.31->yfinance->-r ./requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.31->yfinance->-r ./requirements.txt (line 2)) (1.26.12)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.5-py3-none-any.whl size=138636 sha256=c7d8544484d3e1231587c407d56e602e8f81eec4711376e099824fa66ba1f7c8
#   Stored in directory: /root/.cache/pip/wheels/95/bd/4e/15d1893c245357e4d2353e77456c0be9561d1942ed9fe664ca
# Successfully built peewee
# Installing collected packages: peewee, multitasking, requests, platformdirs, nvidia-nccl-cu12, html5lib, frozendict, xgboost, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Not uninstalling requests at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'requests'. No files were found to uninstall.
# Successfully installed frozendict-2.4.4 html5lib-1.1 multitasking-0.0.11 nvidia-nccl-cu12-2.22.3 peewee-3.17.5 platformdirs-4.2.2 requests-2.32.3 xgboost-2.1.0 yfinance-0.2.40
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e3634c31-dd75-469c-bb95-8fb37ebd73a7' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
